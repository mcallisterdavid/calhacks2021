# %%
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.19.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: six>=1.15.0 in ./opt/anaconda3/lib/python3.8/site-packages (from spotipy) (1.15.0)
# Collecting requests>=2.25.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 3.5 MB/s  eta 0:00:01
# Collecting urllib3>=1.26.0
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 64.0 MB/s eta 0:00:01
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.8/site-packages (from requests>=2.25.0->spotipy) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in ./opt/anaconda3/lib/python3.8/site-packages (from requests>=2.25.0->spotipy) (2.10)
# Collecting charset-normalizer~=2.0.0; python_version >= "3"
#   Downloading charset_normalizer-2.0.7-py3-none-any.whl (38 kB)
# Installing collected packages: urllib3, charset-normalizer, requests, spotipy
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.11
#     Uninstalling urllib3-1.25.11:
#       Successfully uninstalled urllib3-1.25.11
#   Attempting uninstall: requests
#     Found existing installation: requests 2.11.1
#     Uninstalling requests-2.11.1:
#       Successfully uninstalled requests-2.11.1
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# two1 3.10.9 requires mnemonic==0.13, but you'll have mnemonic 0.18 which is incompatible.
# two1 3.10.9 requires protobuf==3.0.0a3, but you'll have protobuf 3.6.1 which is incompatible.
# two1 3.10.9 requires requests<=2.11.1, but you'll have requests 2.26.0 which is incompatible.
# ray 1.5.2 requires click>=7.0, but you'll have click 6.6 which is incompatible.
# ray 1.5.2 requires protobuf>=3.15.3, but you'll have protobuf 3.6.1 which is incompatible.
# google-api-core 1.31.1 requires protobuf>=3.12.0, but you'll have protobuf 3.6.1 which is incompatible.
# binance-dex 0.1.3 requires requests==2.11.1, but you'll have requests 2.26.0 which is incompatible.
# Successfully installed charset-normalizer-2.0.7 requests-2.26.0 spotipy-2.19.0 urllib3-1.26.7

# %%
import numpy as np
import pandas as pd
import sys
import spotipy
import spotipy.util as util

# %% [markdown]
# # Data Imports from Spotify Web API

# %%
# configuring token

SPOTIPY_CLIENT_ID="70c49e55eae64f0a82b313830c6cebf3"
SPOTIPY_CLIENT_SECRET="cb5063c70a514acebca3481a37f15e01"
SPOTIPY_REDIRECT_URI = "http://localhost"
username='axw2001d'
scope="playlist-read-private"
token = util.prompt_for_user_token(username, 
                                   scope, 
                                   client_id=SPOTIPY_CLIENT_ID, 
                                   client_secret=SPOTIPY_CLIENT_SECRET, 
                                   redirect_uri=SPOTIPY_REDIRECT_URI
                                  )
# Out:
# Using `localhost` as redirect URI without a port. Specify a port (e.g. `localhost:8080`) to allow automatic retrieval of authentication code instead of having to copy and paste the URL your browser is redirected to.
# Enter the URL you were redirected to: http://localhost/?code=AQDeAr62BwEho44DNMyPDuyZSw3bUbvv_gg32-N8OMhoGiL2en1uEihAFvXNZfwoI_HM73L-OcbTVzEJ-vTfTJdpVLYIM0-EsM33QJF3fK28fRVx3BItQEbRRhj_2w8I22jKt_YuALhg87SDCAafP4weMp8b8pStt8-BWTG-RXqKpOrsi5R3LkQ9Lw

# %%
def get_user_playlists(username, token):
    if token: 
        sp = spotipy.Spotify(auth=token)
        results = sp.user_playlists(username)
        
        names = [playlist['name'] for playlist in results['items']]
        ids = [playlist['id'] for playlist in results['items']]
        return pd.DataFrame({'Playlist Name': names, 'Playlist ID': ids})
    
    else:
        return ("Can't get token")
    
albertPlaylists = get_user_playlists(username, token)
albertPlaylists
# Out:
#                                    Playlist Name             Playlist ID
# 0                                          chill  0NZG7wQb2vYcZnDbXVhI0c
# 1                                 David + Albert  37i9dQZF1EJKaeFMaOl8eI
# 2                                Meghan + Albert  37i9dQZF1EJLS65dwlarfG
# 3            Two Less Lonely People In the World  1YBSpcRT0vfkMxqQ0cxr99
# 4                                     headspace✨  3YYwXXquXYH1pKrC1gf29z
# 5   lofi hip hop music - beats to relax/study to  0vvXsWCC9xrXsKd4FyS8kM
# 6                            Your Top Songs 2020  37i9dQZF1ELZnfvzQqAiOM
# 7                            Songs I wanna learn  3uYQUUyYNeBgGY6Vz7Tydn
# 8                     Blues Guitar Instrumentals  3a54WQYSUPwjgGmfd4JIII
# 9                                 for the fences  3PZOaNpq2B9vphKihSoW2D
# 10   that one scene in every coming of age movie  4uGsUYiQ4dOVnuXvOsMpHs
# 11                                          loml  07rsz6J6uWCuMucrD9cYK8
# 12                                       DARLING  04HAFZNiiUToc47lsWAsOX
# 13                                     all night  2MOF7eT2ik3NrKevefHWQB
# 14                               put me in coach  2TuKzMm5qoE1lrKR7QrZar
# 15                                     live fast  0G208vRtrayP6mzMLARQco
# 16                                        frames  6RG2Cc0KJeENbIJhCK7Ud5
# 17                                      classics  2fCxs9Aqqb5BMmMMcU6ri5
# 18                                 DROP DROP UZI  2NQemdvdAfjpxKymXLilBK
# 19                                       worship  2AjCPUIb7dHBOkkt586QOy
# 20                                             💯  0eGld1CBicWiGfWPfsU7YI
# 21                                          2020  46KhL8DsgM6QHP7z0UZmtH
# 22                                   CHILL EDM 🍁  0rA7eold66Wk05o4irdrqq
# 23                           Your Top Songs 2019  37i9dQZF1EtiNSswF4uVdj
# 24                                     campfires  15tcSo4UXop6OAj5pDz9Dx
# 25                                      cruising  4VxpiqSAza8WGA3uR3H4bc
# 26                                      hilltops  7sRBeF6snaxrhjdF7kfDAb
# 27                                i love my life  6MRBF2eK1WGiKcQIzK7qPB
# 28                                          jams  4yiCJ2AuaqScoRlLavKb06
# 29                                       summery  0McdFnnfRD5wgOKogG8d0w
# 30                                 Jazz Classics  37i9dQZF1DXbITWG1ZJKYt
# 31                                Piano Classics  7hXPli2ds4vLmFiZ8wmMkz
# 32                                   i wanna eat  1qv6SXfbyIC5v4CyywZqPB
# 33                                         m2k19  0zbY3ApErtUtUszUG95IXQ
# 34                                         youth  2zArbdEBgJHdCkIPqMKZ5N
# 35                              old chinese shit  1Jmj9VbbccOFYaGo9Sm9Jt
# 36                                           2am  19PZZiNj32USaB3uCkRO4D
# 37                            dont wanna wake up  4Dg8gc7IKDVc8ugIke4mgA
# 38                                        old me  2SAxt7xz0kgTS44RRNjkVl
# 39                                          papi  5izX1PruqYLQ23LyBs32FY
# 40                                             🌮  4QRfc9wgbhI1xUsdSlZcgc
# 41                                       destiny  6uaZTiI0CZ5B5jKTVVgtfm
# 42                            middle school shit  3f9MoQmZMA4vfez0pO7E5Y
# 43                                        raw af  2uu20ENdvkskinQMvcBCHC
# 44                                       pastels  2VUyotveVY23XTqNIf6fHk
# 45                                          poop  6Fibbm3KVcXH38aXE3yYeR
# 46                                           在哪里  6QsZGSAtDvrntUPzlRQ8fF
# 47                               Obsolete Allure  1M6AAgxzQqP3iwJyyV3hWF

# %%
def getPlaylistSongs(username, playlistID, token):
    
    features_list = ["artist", "album", "album_release_date", "track_name", "track_id", "explicit", "popularity", "danceability", "energy", "key", "loudness", "mode", "speechiness","instrumentalness","liveness","valence","tempo", "duration_ms","time_signature"]
    df = pd.DataFrame(columns = features_list)
    
    if token:
        sp = spotipy.Spotify(auth=token)
        results = sp.user_playlist_tracks(username, playlistID)
        tracks = results['items']
        
        while results['next']:
            results = sp.next(results)
            tracks.extend(results['items'])
        
        for item in tracks:
            track = item['track']
            if track == None:
                continue
            features = {}
            
            # get metadata
            features['added_time'] = item['added_at']
            if len(track['album']['artists']) > 0:
                features['artist'] = track['album']['artists'][0]['name']
            else: 
                features['artist'] = None
            features['album_release_date'] = track['album']['release_date']
            features['album'] = track['album']['name']
            features['track_name'] = track['name']
            features['track_id'] = track['id']
            features['explicit'] = track['explicit']
            features['popularity'] = track['popularity']
            
            # get audio features
            if features['track_id'] == None or sp.audio_features(features['track_id']) == None:
                continue
                
            audio_features = sp.audio_features(features['track_id'])[0]
            for feature in features_list[7:]: # this splice is hard coded, must update if changing features
                features[feature] = audio_features[feature]
            
            # concat dataframes
            track_df = pd.DataFrame(features, index=[0])
            df = pd.concat([df, track_df], ignore_index=True)
            
        return df
    else:
        return ("Can't get token for", username)

playlistSongs = getPlaylistSongs(username, "2NQemdvdAfjpxKymXLilBK", token)
playlistSongs
# Out:
#                    artist                                              album  \
# 0     HoodRich Pablo Juan                                         Zambamafoo
# 1         Various Artists                                       DJ Worldtour
# 2            Trippie Redd                             A Love Letter To You 2
# 3            Lil Uzi Vert                                      Luv Is Rage 2
# 4               Sheck Wes                                           Mo Bamba
# ...                   ...                                                ...
# 1487               Remble                   Rocc Climbing (feat. Lil Yachty)
# 1488                Drake                                Certified Lover Boy
# 1489           Nardo Wick  Who Want Smoke?? (feat. G Herbo, Lil Durk & 21...
# 1490        The Kid LAROI                             F*CK LOVE 3+: OVER YOU
# 1491        The Kid LAROI                             F*CK LOVE 3+: OVER YOU
#
#      album_release_date                                         track_name  \
# 0            2017-07-31                                         Zambamafoo
# 1            2016-09-02        That's My Rule (Intro) [feat. Lil Uzi Vert]
# 2            2017-10-06                                     Woah Woah Woah
# 3            2017-08-25                                           For Real
# 4            2017-09-19                                           Mo Bamba
# ...                 ...                                                ...
# 1487         2021-09-24                   Rocc Climbing (feat. Lil Yachty)
# 1488         2021-09-03                                           N 2 Deep
# 1489         2021-10-08  Who Want Smoke?? (feat. G Herbo, Lil Durk & 21...
# 1490         2021-07-27                                          ATTENTION
# 1491         2021-07-27                                           BAD NEWS
#
#                     track_id explicit popularity  danceability  energy key  \
# 0     3UMpcCyG1Dj0yDb377vu2K     True         46         0.886   0.644   1
# 1     3x4KIuoye6F12loCFckCX3     True          0         0.908   0.695   8
# 2     70NxaxjB8IjX4YxXbT90iX     True         48         0.617   0.773   0
# 3     3tcoEYOZUHKB3RKNByIN13     True         58         0.902   0.673   4
# 4     3QybPutx0Tjk472bBKjNWn     True          0         0.738   0.629   6
# ...                      ...      ...        ...           ...     ...  ..
# 1487  5bBzkJE9BqYTL27webAUCw     True         69         0.832   0.656   4
# 1488  34D6FJysnQioVingDKufuf     True         82         0.507   0.429   2
# 1489  4yNoUQkYf1QF8iYlEzNynH     True         80         0.739   0.740   5
# 1490  5JrljwNvTFN6y7b5a5Nzq7     True         64         0.878   0.583   8
# 1491  6oFJuAS9OYFfMRFJ08SI1S     True         60         0.550   0.533  10
#
#       loudness mode  speechiness instrumentalness  liveness  valence    tempo  \
# 0       -9.284    1       0.2840                0     0.161   0.6640  119.992
# 1       -7.100    1       0.2690                0     0.270   0.5430  144.026
# 2       -4.793    1       0.0397                0     0.204   0.2420  149.006
# 3       -7.481    1       0.4580                0     0.289   0.6150  132.066
# 4       -4.882    0       0.0495          0.00114     0.163   0.3190  146.067
# ...        ...  ...          ...              ...       ...      ...      ...
# 1487    -7.492    0       0.3750         2.13e-06     0.108   0.5620  100.032
# 1488    -7.726    1       0.3260                0     0.109   0.0744   91.000
# 1489    -5.860    0       0.3330                0     0.161   0.4880   75.575
# 1490    -7.053    1       0.0729                0     0.393   0.3200  132.939
# 1491    -6.853    0       0.0441                0     0.120   0.1710   87.480
#
#      duration_ms time_signature            added_time
# 0         173493              4  2018-06-17T16:01:36Z
# 1         166792              4  2018-06-17T16:01:53Z
# 2         222288              4  2018-06-17T16:02:03Z
# 3         177048              4  2018-06-17T16:02:13Z
# 4         180898              4  2018-06-20T09:39:17Z
# ...          ...            ...                   ...
# 1487      175878              4  2021-09-28T00:03:12Z
# 1488      273578              3  2021-10-02T20:51:07Z
# 1489      279853              4  2021-10-11T22:57:49Z
# 1490      104525              4  2021-10-21T18:20:35Z
# 1491      131365              4  2021-10-22T23:46:51Z
#
# [1492 rows x 20 columns]

# %%
import os
os.getcwd()
# Out:
# '/Users/albertwen/GitHub/calhacks2021'

# %%
playlistSongs.to_csv("largeTestPlaylist.csv.gz", compression='gzip')

# %% [markdown]
# # TSNE

# %%
data = pd.read_csv("largeTestPlaylist.csv.gz").iloc[:, 1:]
data.head()
# Out:
#                 artist                   album album_release_date  \
# 0  HoodRich Pablo Juan              Zambamafoo         2017-07-31
# 1      Various Artists            DJ Worldtour         2016-09-02
# 2         Trippie Redd  A Love Letter To You 2         2017-10-06
# 3         Lil Uzi Vert           Luv Is Rage 2         2017-08-25
# 4            Sheck Wes                Mo Bamba         2017-09-19
#
#                                     track_name                track_id  \
# 0                                   Zambamafoo  3UMpcCyG1Dj0yDb377vu2K
# 1  That's My Rule (Intro) [feat. Lil Uzi Vert]  3x4KIuoye6F12loCFckCX3
# 2                               Woah Woah Woah  70NxaxjB8IjX4YxXbT90iX
# 3                                     For Real  3tcoEYOZUHKB3RKNByIN13
# 4                                     Mo Bamba  3QybPutx0Tjk472bBKjNWn
#
#    explicit  popularity  danceability  energy  key  loudness  mode  \
# 0      True          46         0.886   0.644    1    -9.284     1
# 1      True           0         0.908   0.695    8    -7.100     1
# 2      True          48         0.617   0.773    0    -4.793     1
# 3      True          58         0.902   0.673    4    -7.481     1
# 4      True           0         0.738   0.629    6    -4.882     0
#
#    speechiness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0       0.2840           0.00000     0.161    0.664  119.992       173493
# 1       0.2690           0.00000     0.270    0.543  144.026       166792
# 2       0.0397           0.00000     0.204    0.242  149.006       222288
# 3       0.4580           0.00000     0.289    0.615  132.066       177048
# 4       0.0495           0.00114     0.163    0.319  146.067       180898
#
#    time_signature            added_time
# 0               4  2018-06-17T16:01:36Z
# 1               4  2018-06-17T16:01:53Z
# 2               4  2018-06-17T16:02:03Z
# 3               4  2018-06-17T16:02:13Z
# 4               4  2018-06-20T09:39:17Z

# %%
# one hot encoding data frame
df = data.copy()
df['album_release_date'] = df['album_release_date'].str.slice(0, 4)
df['added_time'] = df['added_time'].str.slice(0, 4)
df.index = df['track_id']
df = df.drop(['artist', 'album', 'track_name', 'track_id'], axis=1)
df = pd.get_dummies(df)

# also normalize the TSNE columns later

df
# Out:
#                         explicit  popularity  danceability  energy  key  \
# track_id
# 3UMpcCyG1Dj0yDb377vu2K      True          46         0.886   0.644    1
# 3x4KIuoye6F12loCFckCX3      True           0         0.908   0.695    8
# 70NxaxjB8IjX4YxXbT90iX      True          48         0.617   0.773    0
# 3tcoEYOZUHKB3RKNByIN13      True          58         0.902   0.673    4
# 3QybPutx0Tjk472bBKjNWn      True           0         0.738   0.629    6
# ...                          ...         ...           ...     ...  ...
# 5bBzkJE9BqYTL27webAUCw      True          69         0.832   0.656    4
# 34D6FJysnQioVingDKufuf      True          82         0.507   0.429    2
# 4yNoUQkYf1QF8iYlEzNynH      True          80         0.739   0.740    5
# 5JrljwNvTFN6y7b5a5Nzq7      True          64         0.878   0.583    8
# 6oFJuAS9OYFfMRFJ08SI1S      True          60         0.550   0.533   10
#
#                         loudness  mode  speechiness  instrumentalness  \
# track_id
# 3UMpcCyG1Dj0yDb377vu2K    -9.284     1       0.2840          0.000000
# 3x4KIuoye6F12loCFckCX3    -7.100     1       0.2690          0.000000
# 70NxaxjB8IjX4YxXbT90iX    -4.793     1       0.0397          0.000000
# 3tcoEYOZUHKB3RKNByIN13    -7.481     1       0.4580          0.000000
# 3QybPutx0Tjk472bBKjNWn    -4.882     0       0.0495          0.001140
# ...                          ...   ...          ...               ...
# 5bBzkJE9BqYTL27webAUCw    -7.492     0       0.3750          0.000002
# 34D6FJysnQioVingDKufuf    -7.726     1       0.3260          0.000000
# 4yNoUQkYf1QF8iYlEzNynH    -5.860     0       0.3330          0.000000
# 5JrljwNvTFN6y7b5a5Nzq7    -7.053     1       0.0729          0.000000
# 6oFJuAS9OYFfMRFJ08SI1S    -6.853     0       0.0441          0.000000
#
#                         liveness  ...  album_release_date_2016  \
# track_id                          ...
# 3UMpcCyG1Dj0yDb377vu2K     0.161  ...                        0
# 3x4KIuoye6F12loCFckCX3     0.270  ...                        1
# 70NxaxjB8IjX4YxXbT90iX     0.204  ...                        0
# 3tcoEYOZUHKB3RKNByIN13     0.289  ...                        0
# 3QybPutx0Tjk472bBKjNWn     0.163  ...                        0
# ...                          ...  ...                      ...
# 5bBzkJE9BqYTL27webAUCw     0.108  ...                        0
# 34D6FJysnQioVingDKufuf     0.109  ...                        0
# 4yNoUQkYf1QF8iYlEzNynH     0.161  ...                        0
# 5JrljwNvTFN6y7b5a5Nzq7     0.393  ...                        0
# 6oFJuAS9OYFfMRFJ08SI1S     0.120  ...                        0
#
#                         album_release_date_2017  album_release_date_2018  \
# track_id
# 3UMpcCyG1Dj0yDb377vu2K                        1                        0
# 3x4KIuoye6F12loCFckCX3                        0                        0
# 70NxaxjB8IjX4YxXbT90iX                        1                        0
# 3tcoEYOZUHKB3RKNByIN13                        1                        0
# 3QybPutx0Tjk472bBKjNWn                        1                        0
# ...                                         ...                      ...
# 5bBzkJE9BqYTL27webAUCw                        0                        0
# 34D6FJysnQioVingDKufuf                        0                        0
# 4yNoUQkYf1QF8iYlEzNynH                        0                        0
# 5JrljwNvTFN6y7b5a5Nzq7                        0                        0
# 6oFJuAS9OYFfMRFJ08SI1S                        0                        0
#
#                         album_release_date_2019  album_release_date_2020  \
# track_id
# 3UMpcCyG1Dj0yDb377vu2K                        0                        0
# 3x4KIuoye6F12loCFckCX3                        0                        0
# 70NxaxjB8IjX4YxXbT90iX                        0                        0
# 3tcoEYOZUHKB3RKNByIN13                        0                        0
# 3QybPutx0Tjk472bBKjNWn                        0                        0
# ...                                         ...                      ...
# 5bBzkJE9BqYTL27webAUCw                        0                        0
# 34D6FJysnQioVingDKufuf                        0                        0
# 4yNoUQkYf1QF8iYlEzNynH                        0                        0
# 5JrljwNvTFN6y7b5a5Nzq7                        0                        0
# 6oFJuAS9OYFfMRFJ08SI1S                        0                        0
#
#                         album_release_date_2021  added_time_2018  \
# track_id
# 3UMpcCyG1Dj0yDb377vu2K                        0                1
# 3x4KIuoye6F12loCFckCX3                        0                1
# 70NxaxjB8IjX4YxXbT90iX                        0                1
# 3tcoEYOZUHKB3RKNByIN13                        0                1
# 3QybPutx0Tjk472bBKjNWn                        0                1
# ...                                         ...              ...
# 5bBzkJE9BqYTL27webAUCw                        1                0
# 34D6FJysnQioVingDKufuf                        1                0
# 4yNoUQkYf1QF8iYlEzNynH                        1                0
# 5JrljwNvTFN6y7b5a5Nzq7                        1                0
# 6oFJuAS9OYFfMRFJ08SI1S                        1                0
#
#                         added_time_2019  added_time_2020  added_time_2021
# track_id
# 3UMpcCyG1Dj0yDb377vu2K                0                0                0
# 3x4KIuoye6F12loCFckCX3                0                0                0
# 70NxaxjB8IjX4YxXbT90iX                0                0                0
# 3tcoEYOZUHKB3RKNByIN13                0                0                0
# 3QybPutx0Tjk472bBKjNWn                0                0                0
# ...                                 ...              ...              ...
# 5bBzkJE9BqYTL27webAUCw                0                0                1
# 34D6FJysnQioVingDKufuf                0                0                1
# 4yNoUQkYf1QF8iYlEzNynH                0                0                1
# 5JrljwNvTFN6y7b5a5Nzq7                0                0                1
# 6oFJuAS9OYFfMRFJ08SI1S                0                0                1
#
# [1492 rows x 38 columns]

# %%
# %matplotlib notebook
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import time

# %%
# fig, ax = plt.subplots(5, 5)
fig, axs = plt.subplots(5,5,figsize=(8,8), subplot_kw=dict(projection='3d'))

increment = (90 - 20) / 25
perp = 20
for i, ax in enumerate(axs.flat):
    tsne = TSNE(n_components=3, perplexity=perp, n_iter=300)
    tsne_results = tsne.fit_transform(df)
    t1 = tsne_results[:,0]
    t2 = tsne_results[:,1]
    t3 = tsne_results[:,2]
    ax.scatter(xs = t1, ys = t2, zs = t3, cmap='tab10')
    ax.set_xlabel('tsne-one')
    ax.set_ylabel('tsne-two')
    ax.set_zlabel('tsne-three')
    perp += increment

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# np.random.seed(42)
time_start = time.time()
tsne = TSNE(n_components=3, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(df)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))

df['tsne-one'] = tsne_results[:,0]
df['tsne-two'] = tsne_results[:,1]
df['tsne-three'] = tsne_results[:,2]
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 1492 samples in 0.002s...
# [t-SNE] Computed neighbors for 1492 samples in 0.043s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1492
# [t-SNE] Computed conditional probabilities for sample 1492 / 1492
# [t-SNE] Mean sigma: 39.789378
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 48.325100
# [t-SNE] KL divergence after 300 iterations: 0.273387
# t-SNE done! Time elapsed: 1.44893479347229 seconds

# %%
df.columns
# Out:
# Index(['explicit', 'popularity', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'instrumentalness', 'liveness', 'valence',
#        'tempo', 'duration_ms', 'time_signature', 'album_release_date_1988',
#        'album_release_date_1996', 'album_release_date_2003',
#        'album_release_date_2004', 'album_release_date_2005',
#        'album_release_date_2007', 'album_release_date_2008',
#        'album_release_date_2009', 'album_release_date_2010',
#        'album_release_date_2011', 'album_release_date_2012',
#        'album_release_date_2013', 'album_release_date_2014',
#        'album_release_date_2015', 'album_release_date_2016',
#        'album_release_date_2017', 'album_release_date_2018',
#        'album_release_date_2019', 'album_release_date_2020',
#        'album_release_date_2021', 'added_time_2018', 'added_time_2019',
#        'added_time_2020', 'added_time_2021', 'tsne-one', 'tsne-two',
#        'tsne-three'],
#       dtype='object')

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
p = ax.scatter(
    xs=df["tsne-one"], 
    ys=df["tsne-two"], 
    zs=df["tsne-three"], 
    c=df['duration_ms'],
    cmap='plasma')

ax.set_xlabel('tsne-one')
ax.set_ylabel('tsne-two')
ax.set_zlabel('tsne-three')
fig.colorbar(p)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## old shit

# %%
len(albertSongs['track_id'].unique())
# Out:
# 60

# %%
albertSongs.shape
# Out:
# (90, 19)

# %%
# pd.DataFrame(pd.json_normalize(track))
# Out:
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#    duration_ms  explicit                                               href  \
# 0       161146     False  https://api.spotify.com/v1/tracks/0zaoWwS8RpE3...
#
#                        id  is_local                           name  \
# 0  0zaoWwS8RpE3LSDdmkg8TC     False  In The Dark (with Jhené Aiko)
#
#    popularity  ...                album.id  \
# 0          65  ...  2kAqjStKcwlDD59H0llhGC
#
#                                         album.images  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                                           album.name album.release_date  \
# 0  Shang-Chi and The Legend of The Ten Rings: The...         2021-09-03
#
#   album.release_date_precision album.total_tracks album.type  \
# 0                          day                 18      album
#
#                               album.uri external_ids.isrc  \
# 0  spotify:album:2kAqjStKcwlDD59H0llhGC      USUM72113050
#
#                                external_urls.spotify
# 0  https://open.spotify.com/track/0zaoWwS8RpE3LSD...
#
# [1 rows x 29 columns]

# %%
# track.keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
# track
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1AhjOkOLkbHUfcHDSErXQs'},
#     'href': 'https://api.spotify.com/v1/artists/1AhjOkOLkbHUfcHDSErXQs',
#     'id': '1AhjOkOLkbHUfcHDSErXQs',
#     'name': '88rising',
#     'type': 'artist',
#     'uri': 'spotify:artist:1AhjOkOLkbHUfcHDSErXQs'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2kxP07DLgs4xlWz8YHlvfh'},
#     'href': 'https://api.spotify.com/v1/artists/2kxP07DLgs4xlWz8YHlvfh',
#     'id': '2kxP07DLgs4xlWz8YHlvfh',
#     'name': 'NIKI',
#     'type': 'artist',
#     'uri': 'spotify:artist:2kxP07DLgs4xlWz8YHlvfh'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/540vIaP2JwjQb9dm3aArA4'},
#     'href': 'https://api.spotify.com/v1/artists/540vIaP2JwjQb9dm3aArA4',
#     'id': '540vIaP2JwjQb9dm3aArA4',
#     'name': 'DJ Snake',
#     'type': 'artist',
#     'uri': 'spotify:artist:540vIaP2JwjQb9dm3aArA4'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2kAqjStKcwlDD59H0llhGC'},
#   'href': 'https://api.spotify.com/v1/albums/2kAqjStKcwlDD59H0llhGC',
#   'id': '2kAqjStKcwlDD59H0llhGC',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2735843d11205f6dd6a2ab5f967',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e025843d11205f6dd6a2ab5f967',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048515843d11205f6dd6a2ab5f967',
#     'width': 64}],
#   'name': 'Shang-Chi and The Legend of The Ten Rings: The Album',
#   'release_date': '2021-09-03',
#   'release_date_precision': 'day',
#   'total_tracks': 18,
#   'type': 'album',
#   'uri': 'spotify:album:2kAqjStKcwlDD59H0llhGC'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1zNqQNIdeOUZHb8zbZRFMX'},
#    'href': 'https://api.spotify.com/v1/artists/1zNqQNIdeOUZHb8zbZRFMX',
#    'id': '1zNqQNIdeOUZHb8zbZRFMX',
#    'name': 'Swae Lee',
#    'type': 'artist',
#    'uri': 'spotify:artist:1zNqQNIdeOUZHb8zbZRFMX'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZS223C6JyBfXasXxrRqOk'},
#    'href': 'https://api.spotify.com/v1/artists/5ZS223C6JyBfXasXxrRqOk',
#    'id': '5ZS223C6JyBfXasXxrRqOk',
#    'name': 'Jhené Aiko',
#    'type': 'artist',
#    'uri': 'spotify:artist:5ZS223C6JyBfXasXxrRqOk'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RU',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'disc_number': 1,
#  'duration_ms': 161146,
#  'explicit': False,
#  'external_ids': {'isrc': 'USUM72113050'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/0zaoWwS8RpE3LSDdmkg8TC'},
#  'href': 'https://api.spotify.com/v1/tracks/0zaoWwS8RpE3LSDdmkg8TC',
#  'id': '0zaoWwS8RpE3LSDdmkg8TC',
#  'is_local': False,
#  'name': 'In The Dark (with Jhené Aiko)',
#  'popularity': 65,
#  'preview_url': 'https://p.scdn.co/mp3-preview/1dcbe5a3f0b573cc5dbd65a37923f2e3f8448633?cid=70c49e55eae64f0a82b313830c6cebf3',
#  'track_number': 3,
#  'type': 'track',
#  'uri': 'spotify:track:0zaoWwS8RpE3LSDdmkg8TC'}

# %%
# def get_saved_songs(token):
    
#     features_list = ["artist", "album", "album_release_date", "track_name", "track_id", "explicit", "popularity", "danceability", "energy", "key", "loudness", "mode", "speechiness","instrumentalness","liveness","valence","tempo", "duration_ms","time_signature"]
#     df = pd.DataFrame(columns = features_list)
    
#     if token:
#         sp = spotipy.Spotify(auth=token)
# #         results = sp.current_user_saved_tracks()
#         results = sp.current_user_top_tracks(limit = 40, offset=0, time_range='long_term')
#         saved_songs = results['items']

# #         print(saved_songs[0], '\n')
# #         print(saved_songs[0].keys())
        
#         num_pages = 0
#         offset = 0
#         number = 30
#         while results['next']:
#             results = sp.current_user_top_tracks(limit=number, offset=offset, time_range='long_term')
#             offset += number
# #             results = sp.next(results)
#             saved_songs.extend(results['items'])
# #             num_pages += 1
        
#         for track in saved_songs:
#             features = {}
            
#             # get metadata
#             features['artist'] = track['album']['artists'][0]['name']
#             features['album_release_date'] = track['album']['release_date']
#             features['album'] = track['album']['name']
#             features['track_name'] = track['name']
#             features['track_id'] = track['id']
#             features['explicit'] = track['explicit']
#             features['popularity'] = track['popularity']
            
#             # get audio features
#             audio_features = sp.audio_features(features['track_id'])[0]
#             for feature in features_list[7:]: # this splice is hard coded, must update if changing features
#                 features[feature] = audio_features[feature]
            
#             # concat dataframes
#             track_df = pd.DataFrame(features, index=[0])
#             df = pd.concat([df, track_df], ignore_index=True)
            
#         return df
#     else:
#         return ("Can't get token for", username)

# albertSongs = get_saved_songs(token)
# albertSongs
