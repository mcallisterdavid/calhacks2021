# %%
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.19.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: six>=1.15.0 in ./opt/anaconda3/lib/python3.8/site-packages (from spotipy) (1.15.0)
# Collecting requests>=2.25.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 3.5 MB/s  eta 0:00:01
# Collecting urllib3>=1.26.0
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 64.0 MB/s eta 0:00:01
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.8/site-packages (from requests>=2.25.0->spotipy) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in ./opt/anaconda3/lib/python3.8/site-packages (from requests>=2.25.0->spotipy) (2.10)
# Collecting charset-normalizer~=2.0.0; python_version >= "3"
#   Downloading charset_normalizer-2.0.7-py3-none-any.whl (38 kB)
# Installing collected packages: urllib3, charset-normalizer, requests, spotipy
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.11
#     Uninstalling urllib3-1.25.11:
#       Successfully uninstalled urllib3-1.25.11
#   Attempting uninstall: requests
#     Found existing installation: requests 2.11.1
#     Uninstalling requests-2.11.1:
#       Successfully uninstalled requests-2.11.1
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# two1 3.10.9 requires mnemonic==0.13, but you'll have mnemonic 0.18 which is incompatible.
# two1 3.10.9 requires protobuf==3.0.0a3, but you'll have protobuf 3.6.1 which is incompatible.
# two1 3.10.9 requires requests<=2.11.1, but you'll have requests 2.26.0 which is incompatible.
# ray 1.5.2 requires click>=7.0, but you'll have click 6.6 which is incompatible.
# ray 1.5.2 requires protobuf>=3.15.3, but you'll have protobuf 3.6.1 which is incompatible.
# google-api-core 1.31.1 requires protobuf>=3.12.0, but you'll have protobuf 3.6.1 which is incompatible.
# binance-dex 0.1.3 requires requests==2.11.1, but you'll have requests 2.26.0 which is incompatible.
# Successfully installed charset-normalizer-2.0.7 requests-2.26.0 spotipy-2.19.0 urllib3-1.26.7

# %%
import numpy as np
import pandas as pd
import sys
import spotipy
import spotipy.util as util
import collections
# %matplotlib notebook
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import time

# %% [markdown]
# # Data Imports from Spotify Web API

# %%
# configuring token

SPOTIPY_CLIENT_ID="70c49e55eae64f0a82b313830c6cebf3"
SPOTIPY_CLIENT_SECRET="cb5063c70a514acebca3481a37f15e01"
SPOTIPY_REDIRECT_URI = "http://localhost"
username='axw2001d'
scope="playlist-read-private"
token = util.prompt_for_user_token(username, 
                                   scope, 
                                   client_id=SPOTIPY_CLIENT_ID, 
                                   client_secret=SPOTIPY_CLIENT_SECRET, 
                                   redirect_uri=SPOTIPY_REDIRECT_URI
                                  )

# %%
def getUserPlaylists(username, token):
    if token: 
        sp = spotipy.Spotify(auth=token)
        results = sp.user_playlists(username)
        
        names = [playlist['name'] for playlist in results['items']]
        ids = [playlist['id'] for playlist in results['items']]
        return pd.DataFrame({'Playlist Name': names, 'Playlist ID': ids})
    
    else:
        return ("Can't get token")
    
albertPlaylists = getUserPlaylists(username, token)
albertPlaylists
# Out:
#                                    Playlist Name             Playlist ID
# 0                                          chill  0NZG7wQb2vYcZnDbXVhI0c
# 1                                 David + Albert  37i9dQZF1EJKaeFMaOl8eI
# 2                                Meghan + Albert  37i9dQZF1EJLS65dwlarfG
# 3            Two Less Lonely People In the World  1YBSpcRT0vfkMxqQ0cxr99
# 4                                     headspace✨  3YYwXXquXYH1pKrC1gf29z
# 5   lofi hip hop music - beats to relax/study to  0vvXsWCC9xrXsKd4FyS8kM
# 6                            Your Top Songs 2020  37i9dQZF1ELZnfvzQqAiOM
# 7                            Songs I wanna learn  3uYQUUyYNeBgGY6Vz7Tydn
# 8                     Blues Guitar Instrumentals  3a54WQYSUPwjgGmfd4JIII
# 9                                 for the fences  3PZOaNpq2B9vphKihSoW2D
# 10   that one scene in every coming of age movie  4uGsUYiQ4dOVnuXvOsMpHs
# 11                                          loml  07rsz6J6uWCuMucrD9cYK8
# 12                                       DARLING  04HAFZNiiUToc47lsWAsOX
# 13                                     all night  2MOF7eT2ik3NrKevefHWQB
# 14                               put me in coach  2TuKzMm5qoE1lrKR7QrZar
# 15                                     live fast  0G208vRtrayP6mzMLARQco
# 16                                        frames  6RG2Cc0KJeENbIJhCK7Ud5
# 17                                      classics  2fCxs9Aqqb5BMmMMcU6ri5
# 18                                 DROP DROP UZI  2NQemdvdAfjpxKymXLilBK
# 19                                       worship  2AjCPUIb7dHBOkkt586QOy
# 20                                             💯  0eGld1CBicWiGfWPfsU7YI
# 21                                          2020  46KhL8DsgM6QHP7z0UZmtH
# 22                                   CHILL EDM 🍁  0rA7eold66Wk05o4irdrqq
# 23                           Your Top Songs 2019  37i9dQZF1EtiNSswF4uVdj
# 24                                     campfires  15tcSo4UXop6OAj5pDz9Dx
# 25                                      cruising  4VxpiqSAza8WGA3uR3H4bc
# 26                                      hilltops  7sRBeF6snaxrhjdF7kfDAb
# 27                                i love my life  6MRBF2eK1WGiKcQIzK7qPB
# 28                                          jams  4yiCJ2AuaqScoRlLavKb06
# 29                                       summery  0McdFnnfRD5wgOKogG8d0w
# 30                                 Jazz Classics  37i9dQZF1DXbITWG1ZJKYt
# 31                                Piano Classics  7hXPli2ds4vLmFiZ8wmMkz
# 32                                   i wanna eat  1qv6SXfbyIC5v4CyywZqPB
# 33                                         m2k19  0zbY3ApErtUtUszUG95IXQ
# 34                                         youth  2zArbdEBgJHdCkIPqMKZ5N
# 35                              old chinese shit  1Jmj9VbbccOFYaGo9Sm9Jt
# 36                                           2am  19PZZiNj32USaB3uCkRO4D
# 37                            dont wanna wake up  4Dg8gc7IKDVc8ugIke4mgA
# 38                                        old me  2SAxt7xz0kgTS44RRNjkVl
# 39                                          papi  5izX1PruqYLQ23LyBs32FY
# 40                                             🌮  4QRfc9wgbhI1xUsdSlZcgc
# 41                                       destiny  6uaZTiI0CZ5B5jKTVVgtfm
# 42                            middle school shit  3f9MoQmZMA4vfez0pO7E5Y
# 43                                        raw af  2uu20ENdvkskinQMvcBCHC
# 44                                       pastels  2VUyotveVY23XTqNIf6fHk
# 45                                          poop  6Fibbm3KVcXH38aXE3yYeR
# 46                                           在哪里  6QsZGSAtDvrntUPzlRQ8fF
# 47                               Obsolete Allure  1M6AAgxzQqP3iwJyyV3hWF

# %%
def getPlaylistSongs(username, playlistID, token):
    
#     playlist = getUserPlaylists(username, token)
#     playlistID = list(playlist[playlist['Playlist Name'] == playlistName]['Playlist ID'])[0]

    features_list = ["artist", "album", "album_release_date", "album_cover_url", "track_name", "track_id", 
                         "explicit", "popularity", "danceability", "energy", "key", 
                         "loudness", "mode", "speechiness","instrumentalness","liveness",
                         "valence","tempo", "duration_ms","time_signature"]
    df = pd.DataFrame(columns = features_list[:7])
    
    if token:
        sp = spotipy.Spotify(auth=token)
        results = sp.user_playlist_tracks(username, playlistID, limit=70)
        tracks = results['items']
        while results['next']:
            results = sp.next(results)
            tracks.extend(results['items'])
        
        for item in tracks:
            track = item['track']
            if track == None or track['id'] == None:
                continue
            features = {}
            
            # get metadata
            features['added_time'] = item['added_at']
            if len(track['album']['artists']) > 0:
                features['artist'] = track['album']['artists'][0]['name']
            else: 
                features['artist'] = None
            features['album_release_date'] = track['album']['release_date']
            features['album'] = track['album']['name']
            features['album_cover_url'] = track['album']['images'][0]['url']
            features['track_name'] = track['name']
            features['track_id'] = track['id']
            features['explicit'] = track['explicit']
            features['popularity'] = track['popularity']
            
            # concat dataframes
            track_df = pd.DataFrame(features, index=[0])
            df = pd.concat([df, track_df], ignore_index=True)
            
        track_ids = df['track_id']
        audio_features = []
        while len(track_ids) > 100:
            audio_features += sp.audio_features(','.join(track_ids[0:100]))
            track_ids = track_ids[100:]
        audio_features += sp.audio_features(','.join(track_ids))
        
        for feature in features_list[8:]:
            df[feature] = [track[feature] for track in audio_features]
        
        return df
    else:
        return ("Can't get token for", username)

# %%
# playlistSongs = getPlaylistSongs(username, "2NQemdvdAfjpxKymXLilBK", token)
playlistSongs = getPlaylistSongs(username, "0vvXsWCC9xrXsKd4FyS8kM", token)
playlistSongs
# Out:
#               artist                 album album_release_date  \
# 0              Amess  A place above heaven         2021-07-11
# 1          DaniSogen   A World of Illusion         2021-10-21
# 2            iamalex                  Silk         2021-08-08
# 3       Kurt Stewart            Pegan Hill         2021-04-28
# 4              Jhove           dream tapes         2021-07-19
# ..               ...                   ...                ...
# 295     Dimension 32       Silent Emotions         2021-09-27
# 296       Team Astro             Travelers         2021-02-01
# 297            Kupla       Kingdom in Blue         2020-02-29
# 298          Krynoze         A World After         2021-10-05
# 299  Dillan Witherow        Before Sunrise         2021-03-09
#
#                                        album_cover_url  \
# 0    https://i.scdn.co/image/ab67616d0000b273be5dac...
# 1    https://i.scdn.co/image/ab67616d0000b273040998...
# 2    https://i.scdn.co/image/ab67616d0000b27322ad48...
# 3    https://i.scdn.co/image/ab67616d0000b273879c54...
# 4    https://i.scdn.co/image/ab67616d0000b273025a7e...
# ..                                                 ...
# 295  https://i.scdn.co/image/ab67616d0000b273d9b8ea...
# 296  https://i.scdn.co/image/ab67616d0000b273e0b5c6...
# 297  https://i.scdn.co/image/ab67616d0000b27365de43...
# 298  https://i.scdn.co/image/ab67616d0000b2737524cd...
# 299  https://i.scdn.co/image/ab67616d0000b273b6fc16...
#
#                  track_name                track_id explicit  \
# 0             Friday nights  72ipUmRhSVs9E4knzBRozk    False
# 1                Pathfinder  7I7GgJ5WN4yL7y6A79nfh1    False
# 2           Sunday Sleeping  3wJFDdh6KjENpemdkSU4Gg    False
# 3                    Adrift  1SZnu0wclsSROTitZPP4Yf    False
# 4    i don't wanna grow old  1CCg6gRdBE6HJ8MzwCV6HZ    False
# ..                      ...                     ...      ...
# 295      Raining In My Head  2uv1gNThLENcJjbgDMSLYC    False
# 296    Stop Calling Me Cute  4ycWuFxVYS1bWAqhBPEQvo    False
# 297       Sleepy Little One  26JfvzihGUTJs8vFEi4Nkn    False
# 298           Breaking Dawn  7oABvtgUnr0Oly5TjMG0NS    False
# 299                Rose Bay  2BkIEiqVNoMbPa3mVVo9j3    False
#
#                added_time  popularity  danceability  ...  key  loudness  mode  \
# 0    2021-10-21T09:37:48Z        57.0         0.723  ...    3   -14.098     1
# 1    2021-10-21T09:37:48Z        52.0         0.397  ...    2   -18.056     0
# 2    2021-10-21T09:37:48Z        57.0         0.677  ...    0   -14.147     1
# 3    2021-10-21T09:37:48Z        58.0         0.587  ...    6   -22.150     0
# 4    2021-10-21T09:37:48Z        55.0         0.641  ...    8   -15.486     1
# ..                    ...         ...           ...  ...  ...       ...   ...
# 295  2021-10-21T09:37:48Z        58.0         0.597  ...    5   -20.532     1
# 296  2021-10-21T09:37:48Z        47.0         0.712  ...   11   -12.658     1
# 297  2021-10-21T09:37:48Z         1.0         0.580  ...    6   -11.073     0
# 298  2021-10-21T09:37:48Z        57.0         0.592  ...    8   -17.372     0
# 299  2021-10-21T09:37:48Z        48.0         0.697  ...    5   -13.209     1
#
#      speechiness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0         0.1030             0.877    0.1200   0.0853   79.992       162000
# 1         0.0490             0.545    0.3600   0.1790  118.951       168000
# 2         0.0370             0.872    0.0813   0.0604  132.012       109091
# 3         0.0345             0.827    0.0999   0.2330  109.905       124174
# 4         0.0390             0.936    0.3830   0.0828   75.004       163242
# ..           ...               ...       ...      ...      ...          ...
# 295       0.0349             0.946    0.0979   0.1300  120.028       128625
# 296       0.0416             0.951    0.0992   0.2060   80.022       158438
# 297       0.0531             0.643    0.7070   0.1340   77.996       153846
# 298       0.0374             0.924    0.3580   0.1820  139.983       156219
# 299       0.1010             0.632    0.2640   0.7090  147.990       116757
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 295               4
# 296               4
# 297               4
# 298               4
# 299               4
#
# [300 rows x 21 columns]

# %% [markdown]
# # TSNE

# %%
def cleanData(df):
    
    # getting only month of release date and added time
    df = df.drop_duplicates()
    df['album_release_date'] = df['album_release_date'].str.slice(0, 4)
    df['added_time'] = df['added_time'].str.slice(0, 4)
    
    # setting index and dropping irrelevant columns
    df.index = df['track_id']
    df = df[~df.index.duplicated(keep='first')]

    ohe = df.drop(['artist', 'album', 'track_name', 'track_id', 'album_cover_url'], axis=1)
    
    # add a few columns as categorical features
    ohe['key'] = ohe['key'].astype(str)
    ohe['mode'] = ohe['mode'].astype(str)
    ohe['time_signature'] = ohe['time_signature'].astype(str)
    ohe['popularity'] = ohe['popularity'].astype(int)
        
    # getting dummies
    ohe = pd.get_dummies(ohe)
        
    # normalization
    columns_to_normalize = ['popularity', 'danceability', 'energy', 
                                'loudness', 'speechiness', 'instrumentalness', 
                                'liveness', 'valence', 'tempo', 'duration_ms']
    
    # store mean and std of features before normalization, for restoration later
    metadata = {}
    
    weighted_cols = ['popularity', 'danceability', 'energy', 'instrumentalness']
    for column in columns_to_normalize:
        scale = 1
        if column in weighted_cols:
            scale = .2
        metadata[column] = (ohe[column].mean(), scale * ohe[column].std())
        ohe[column] = (ohe[column] - ohe[column].mean()) / ohe[column].std()
    
    ohe['artist'] = df['artist']
    ohe['album'] = df['album']
    ohe['track_name'] = df['track_name']
    
#     weighted_cols = ['popularity', 'danceability', 'energy', 'instrumentalness']
    for col in weighted_cols:
        ohe[col] = 5 * ohe[col]
    
    ohe['album_cover_url'] = df['album_cover_url']
    
    return ohe, metadata

def generate_TSNE(df: pd.DataFrame()):
    normed_df, metadata = cleanData(df)
    
    # np.random.seed(42)
    time_start = time.time()
    tsne = TSNE(n_components=3, verbose=1, perplexity=40, n_iter=300)
    tsne_results = tsne.fit_transform(normed_df[normed_df.columns.difference(['artist', 'album', 'track_name', 'album_cover_url'])])
    print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
    
    normed_df['tsne-one'] = tsne_results[:,0] / np.sqrt(tsne_results[:,0].std())
    normed_df['tsne-two'] = tsne_results[:,1] / np.sqrt(tsne_results[:,1].std())
    normed_df['tsne-three'] = tsne_results[:,2] / np.sqrt(tsne_results[:,2].std())
    
    for column in list(metadata.keys()):
        normed_df[column] = normed_df[column]*metadata[column][1] + metadata[column][0]

    # normed_df['tsne-one'] = [np.log(x) if x > 0 else -np.log(-x) for x in tsne_results[:,0]]
    # normed_df['tsne-two'] = [np.log(y) if y > 0 else -np.log(-y) for y in tsne_results[:,1]]
    # normed_df['tsne-three'] = [np.log(z) if z > 0 else -np.log(-z) for z in tsne_results[:,2]]
    
    return normed_df

# %%
test = generate_TSNE(playlistSongs)
test
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 300 samples in 0.000s...
# [t-SNE] Computed neighbors for 300 samples in 0.010s...
# [t-SNE] Computed conditional probabilities for sample 300 / 300
# [t-SNE] Mean sigma: 3.130844
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 121.976105
# [t-SNE] KL divergence after 300 iterations: 3.006198
# t-SNE done! Time elapsed: 0.3828420639038086 seconds
#                         popularity  danceability  energy  loudness  \
# track_id
# 72ipUmRhSVs9E4knzBRozk        57.0         0.723  0.2520   -14.098
# 7I7GgJ5WN4yL7y6A79nfh1        52.0         0.397  0.2020   -18.056
# 3wJFDdh6KjENpemdkSU4Gg        57.0         0.677  0.2280   -14.147
# 1SZnu0wclsSROTitZPP4Yf        58.0         0.587  0.0548   -22.150
# 1CCg6gRdBE6HJ8MzwCV6HZ        55.0         0.641  0.2260   -15.486
# ...                            ...           ...     ...       ...
# 2uv1gNThLENcJjbgDMSLYC        58.0         0.597  0.1580   -20.532
# 4ycWuFxVYS1bWAqhBPEQvo        47.0         0.712  0.1730   -12.658
# 26JfvzihGUTJs8vFEi4Nkn         1.0         0.580  0.4390   -11.073
# 7oABvtgUnr0Oly5TjMG0NS        57.0         0.592  0.1800   -17.372
# 2BkIEiqVNoMbPa3mVVo9j3        48.0         0.697  0.4190   -13.209
#
#                         speechiness  instrumentalness  liveness  valence  \
# track_id
# 72ipUmRhSVs9E4knzBRozk       0.1030             0.877    0.1200   0.0853
# 7I7GgJ5WN4yL7y6A79nfh1       0.0490             0.545    0.3600   0.1790
# 3wJFDdh6KjENpemdkSU4Gg       0.0370             0.872    0.0813   0.0604
# 1SZnu0wclsSROTitZPP4Yf       0.0345             0.827    0.0999   0.2330
# 1CCg6gRdBE6HJ8MzwCV6HZ       0.0390             0.936    0.3830   0.0828
# ...                             ...               ...       ...      ...
# 2uv1gNThLENcJjbgDMSLYC       0.0349             0.946    0.0979   0.1300
# 4ycWuFxVYS1bWAqhBPEQvo       0.0416             0.951    0.0992   0.2060
# 26JfvzihGUTJs8vFEi4Nkn       0.0531             0.643    0.7070   0.1340
# 7oABvtgUnr0Oly5TjMG0NS       0.0374             0.924    0.3580   0.1820
# 2BkIEiqVNoMbPa3mVVo9j3       0.1010             0.632    0.2640   0.7090
#
#                           tempo  duration_ms  ...  time_signature_3  \
# track_id                                      ...
# 72ipUmRhSVs9E4knzBRozk   79.992     162000.0  ...                 0
# 7I7GgJ5WN4yL7y6A79nfh1  118.951     168000.0  ...                 0
# 3wJFDdh6KjENpemdkSU4Gg  132.012     109091.0  ...                 0
# 1SZnu0wclsSROTitZPP4Yf  109.905     124174.0  ...                 0
# 1CCg6gRdBE6HJ8MzwCV6HZ   75.004     163242.0  ...                 0
# ...                         ...          ...  ...               ...
# 2uv1gNThLENcJjbgDMSLYC  120.028     128625.0  ...                 0
# 4ycWuFxVYS1bWAqhBPEQvo   80.022     158438.0  ...                 0
# 26JfvzihGUTJs8vFEi4Nkn   77.996     153846.0  ...                 0
# 7oABvtgUnr0Oly5TjMG0NS  139.983     156219.0  ...                 0
# 2BkIEiqVNoMbPa3mVVo9j3  147.990     116757.0  ...                 0
#
#                         time_signature_4  time_signature_5           artist  \
# track_id
# 72ipUmRhSVs9E4knzBRozk                 1                 0            Amess
# 7I7GgJ5WN4yL7y6A79nfh1                 1                 0        DaniSogen
# 3wJFDdh6KjENpemdkSU4Gg                 1                 0          iamalex
# 1SZnu0wclsSROTitZPP4Yf                 1                 0     Kurt Stewart
# 1CCg6gRdBE6HJ8MzwCV6HZ                 1                 0            Jhove
# ...                                  ...               ...              ...
# 2uv1gNThLENcJjbgDMSLYC                 1                 0     Dimension 32
# 4ycWuFxVYS1bWAqhBPEQvo                 1                 0       Team Astro
# 26JfvzihGUTJs8vFEi4Nkn                 1                 0            Kupla
# 7oABvtgUnr0Oly5TjMG0NS                 1                 0          Krynoze
# 2BkIEiqVNoMbPa3mVVo9j3                 1                 0  Dillan Witherow
#
#                                        album              track_name  \
# track_id
# 72ipUmRhSVs9E4knzBRozk  A place above heaven           Friday nights
# 7I7GgJ5WN4yL7y6A79nfh1   A World of Illusion              Pathfinder
# 3wJFDdh6KjENpemdkSU4Gg                  Silk         Sunday Sleeping
# 1SZnu0wclsSROTitZPP4Yf            Pegan Hill                  Adrift
# 1CCg6gRdBE6HJ8MzwCV6HZ           dream tapes  i don't wanna grow old
# ...                                      ...                     ...
# 2uv1gNThLENcJjbgDMSLYC       Silent Emotions      Raining In My Head
# 4ycWuFxVYS1bWAqhBPEQvo             Travelers    Stop Calling Me Cute
# 26JfvzihGUTJs8vFEi4Nkn       Kingdom in Blue       Sleepy Little One
# 7oABvtgUnr0Oly5TjMG0NS         A World After           Breaking Dawn
# 2BkIEiqVNoMbPa3mVVo9j3        Before Sunrise                Rose Bay
#
#                                                           album_cover_url  \
# track_id
# 72ipUmRhSVs9E4knzBRozk  https://i.scdn.co/image/ab67616d0000b273be5dac...
# 7I7GgJ5WN4yL7y6A79nfh1  https://i.scdn.co/image/ab67616d0000b273040998...
# 3wJFDdh6KjENpemdkSU4Gg  https://i.scdn.co/image/ab67616d0000b27322ad48...
# 1SZnu0wclsSROTitZPP4Yf  https://i.scdn.co/image/ab67616d0000b273879c54...
# 1CCg6gRdBE6HJ8MzwCV6HZ  https://i.scdn.co/image/ab67616d0000b273025a7e...
# ...                                                                   ...
# 2uv1gNThLENcJjbgDMSLYC  https://i.scdn.co/image/ab67616d0000b273d9b8ea...
# 4ycWuFxVYS1bWAqhBPEQvo  https://i.scdn.co/image/ab67616d0000b273e0b5c6...
# 26JfvzihGUTJs8vFEi4Nkn  https://i.scdn.co/image/ab67616d0000b27365de43...
# 7oABvtgUnr0Oly5TjMG0NS  https://i.scdn.co/image/ab67616d0000b2737524cd...
# 2BkIEiqVNoMbPa3mVVo9j3  https://i.scdn.co/image/ab67616d0000b273b6fc16...
#
#                          tsne-one  tsne-two  tsne-three
# track_id
# 72ipUmRhSVs9E4knzBRozk  -0.043418  2.121269    3.280970
# 7I7GgJ5WN4yL7y6A79nfh1  -1.813100 -4.225717    0.844447
# 3wJFDdh6KjENpemdkSU4Gg  -3.534263  4.010233    0.441516
# 1SZnu0wclsSROTitZPP4Yf   2.034005  1.854036   -4.850742
# 1CCg6gRdBE6HJ8MzwCV6HZ  -0.565962  2.673201   -0.038471
# ...                           ...       ...         ...
# 2uv1gNThLENcJjbgDMSLYC -16.392229  0.201830    4.835209
# 4ycWuFxVYS1bWAqhBPEQvo   0.897798  3.272197    1.251686
# 26JfvzihGUTJs8vFEi4Nkn  -1.246161  0.497847    1.619960
# 7oABvtgUnr0Oly5TjMG0NS  -0.937945  4.069756   -2.056388
# 2BkIEiqVNoMbPa3mVVo9j3  -1.581869 -1.742546    5.027111
#
# [300 rows x 39 columns]

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
p = ax.scatter(
    xs=test["tsne-one"], 
    ys=test["tsne-two"], 
    zs=test["tsne-three"], 
    c=test['tempo'],
    cmap='plasma')

ax.set_xlabel('tsne-one')
ax.set_ylabel('tsne-two')
ax.set_zlabel('tsne-three')
fig.colorbar(p)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# fig, ax = plt.subplots(5, 5)
fig, axs = plt.subplots(5,5,figsize=(8,8), subplot_kw=dict(projection='3d'))

increment = (90 - 20) / 25
perp = 20
for i, ax in enumerate(axs.flat):
    tsne = TSNE(n_components=3, perplexity=perp, n_iter=300)
    tsne_results = tsne.fit_transform(largeData)
    t1 = tsne_results[:,0]
    t2 = tsne_results[:,1]
    t3 = tsne_results[:,2]
    ax.scatter(xs = t1, ys = t2, zs = t3, cmap='tab10')
    ax.set_xlabel('tsne-one')
    ax.set_ylabel('tsne-two')
    ax.set_zlabel('tsne-three')
    perp += increment

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # Testing Stuff

# %%
import numpy as np
import pandas as pd
from sklearn.manifold import TSNE
import spotipy
import spotipy.util as util
import time


def tsne_spotify(token, username, playlistID):
    # dataframe of the songs in playlistID
	playlistSongs = getPlaylistSongs(username, playlistID, token)

    # adds three columns to prev df, with TSNE coords
	data = generate_TSNE(playlistSongs) 

	return data[['artist', 'album', 'track_name', 'album_cover_url', 
                    'danceability', 'popularity', 'energy', 'loudness', 'duration_ms',
                    'speechiness', 'instrumentalness', 'liveness', 'tempo', 
                    'tsne-one', 'tsne-two', 'tsne-three']].to_json(orient='index')

# get the playlists for the username and token; not needed for current implementation
def getUserPlaylists(username, token):
    if token: 
        sp = spotipy.Spotify(auth=token)
        results = sp.user_playlists(username)
        
        names = [playlist['name'] for playlist in results['items']]
        ids = [playlist['id'] for playlist in results['items']]
        return pd.DataFrame({'Playlist Name': names, 'Playlist ID': ids})
    
    else:
        return ("Can't get token")
    

def getPlaylistSongs(username, playlistID, token):
    
    # playlist = getUserPlaylists(username, token)
    # playlistID = list(playlist[playlist['Playlist Name'] == playlistName]['Playlist ID'])[0]

    features_list = ["artist", "album", "album_release_date", "album_cover_url", "track_name", "track_id", 
                         "explicit", "popularity", "danceability", "energy", "key", 
                         "loudness", "mode", "speechiness","instrumentalness","liveness",
                         "valence","tempo", "duration_ms","time_signature"]
    df = pd.DataFrame(columns = features_list[:7])
    
    if token:
        sp = spotipy.Spotify(auth=token)
        results = sp.user_playlist_tracks(username, playlistID, limit=70)
        tracks = results['items']
        while results['next']:
            results = sp.next(results)
            tracks.extend(results['items'])
        
        for item in tracks:
            track = item['track']
            if track == None or track['id'] == None:
                continue
            features = {}
            
            # get metadata
            features['added_time'] = item['added_at']
            if len(track['album']['artists']) > 0:
                features['artist'] = track['album']['artists'][0]['name']
            else: 
                features['artist'] = None
            features['album_release_date'] = track['album']['release_date']
            features['album'] = track['album']['name']
            features['album_cover_url'] = track['album']['images'][0]['url']
            features['track_name'] = track['name']
            features['track_id'] = track['id']
            features['explicit'] = track['explicit']
            features['popularity'] = track['popularity']
            
            # concat dataframes
            track_df = pd.DataFrame(features, index=[0])
            df = pd.concat([df, track_df], ignore_index=True)
            
        track_ids = df['track_id']
        audio_features = []
        while len(track_ids) > 100:
            audio_features += sp.audio_features(','.join(track_ids[0:100]))
            track_ids = track_ids[100:]
        audio_features += sp.audio_features(','.join(track_ids))
        
        for feature in features_list[8:]:
            df[feature] = [track[feature] for track in audio_features]
        
        return df
    else:
        return ("Can't get token for", username)


def cleanData(df):
    
    # getting only month of release date and added time
    df = df.drop_duplicates()
    df['album_release_date'] = df['album_release_date'].str.slice(0, 4)
    df['added_time'] = df['added_time'].str.slice(0, 4)
    
    # setting index and dropping irrelevant columns
    df.index = df['track_id']
    df = df[~df.index.duplicated(keep='first')]

    ohe = df.drop(['artist', 'album', 'track_name', 'track_id', 'album_cover_url'], axis=1)
    
    # add a few columns as categorical features
    ohe['key'] = ohe['key'].astype(str)
    ohe['mode'] = ohe['mode'].astype(str)
    ohe['time_signature'] = ohe['time_signature'].astype(str)
    ohe['popularity'] = ohe['popularity'].astype(int)
        
    # getting dummies
    ohe = pd.get_dummies(ohe)
        
    # normalization
    columns_to_normalize = ['popularity', 'danceability', 'energy', 
                                'loudness', 'speechiness', 'instrumentalness', 
                                'liveness', 'valence', 'tempo', 'duration_ms']
    
    # store mean and std of features before normalization, for restoration later
    metadata = {}
    
    weighted_cols = ['popularity', 'danceability', 'energy', 'instrumentalness']
    for column in columns_to_normalize:
        scale = 1
        if column in weighted_cols:
            scale = .2
        metadata[column] = (ohe[column].mean(), scale * ohe[column].std())
        ohe[column] = (ohe[column] - ohe[column].mean()) / ohe[column].std()
    
    ohe['artist'] = df['artist']
    ohe['album'] = df['album']
    ohe['track_name'] = df['track_name']
    
#     weighted_cols = ['popularity', 'danceability', 'energy', 'instrumentalness']
    for col in weighted_cols:
        ohe[col] = 5 * ohe[col]
    
    ohe['album_cover_url'] = df['album_cover_url']
    
    return ohe, metadata

def generate_TSNE(df: pd.DataFrame()):
    normed_df, metadata = cleanData(df)
    
    # np.random.seed(42)
    time_start = time.time()
    tsne = TSNE(n_components=3, verbose=1, perplexity=40, n_iter=300)
    tsne_results = tsne.fit_transform(normed_df[normed_df.columns.difference(['artist', 'album', 'track_name', 'album_cover_url'])])
    print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
    
    normed_df['tsne-one'] = tsne_results[:,0] / np.sqrt(tsne_results[:,0].std())
    normed_df['tsne-two'] = tsne_results[:,1] / np.sqrt(tsne_results[:,1].std())
    normed_df['tsne-three'] = tsne_results[:,2] / np.sqrt(tsne_results[:,2].std())
    
    for column in list(metadata.keys()):
        normed_df[column] = normed_df[column]*metadata[column][1] + metadata[column][0]

    # normed_df['tsne-one'] = [np.log(x) if x > 0 else -np.log(-x) for x in tsne_results[:,0]]
    # normed_df['tsne-two'] = [np.log(y) if y > 0 else -np.log(-y) for y in tsne_results[:,1]]
    # normed_df['tsne-three'] = [np.log(z) if z > 0 else -np.log(-z) for z in tsne_results[:,2]]
    
    return normed_df

playlistID = '2NQemdvdAfjpxKymXLilBK'
test = tsne_spotify(token, username, playlistID)
test
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 1483 samples in 0.003s...
# [t-SNE] Computed neighbors for 1483 samples in 0.142s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1483
# [t-SNE] Computed conditional probabilities for sample 1483 / 1483
# [t-SNE] Mean sigma: 2.147765
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 67.777763
# [t-SNE] KL divergence after 300 iterations: 0.969405
# t-SNE done! Time elapsed: 2.1657474040985107 seconds
# '{"3UMpcCyG1Dj0yDb377vu2K":{"artist":"HoodRich Pablo Juan","album":"Zambamafoo","track_name":"Zambamafoo","album_cover_url":"https:\\/\\/i.scdn.co\\/image\\/ab67616d0000b27319388d33688504565f79aa02","danceability":0.886,"popularity":46.0,"energy":0.644,"loudness":-9.284,"duration_ms":173493.0,"speechiness":0.284,"instrumentalness":0.0,"liveness":0.161,"tempo":119.992,"tsne-one":-0.9549389482,"tsne-two":-2.2938411236,"tsne-three":1.4043984413},"3x4KIuoye6F12loCFckCX3":{"artist":"Various Artists","album":"DJ Worldtour","track_name":"That\'s My Rule (Intro) [feat. Lil Uzi Vert]","album_cover_url":"https:\\/\\/i.scdn.co\\/image\\/ab67616d0000b273005ac5b156cf09c76d9664ca","danceability":0.908,"popularity":0.0,"energy":0.695,"loudness":-7.1,"duration_ms":166792.0,"speechiness":0.269,"instrumentalness":0.0,"liveness":0.27,"tempo":144.026,"tsne-one":-2.5338602066,"tsne-two":-3.3803877831,"tsne-three":-0.7664664984},"70NxaxjB8IjX4YxXbT90iX":{"artist":"Trippie Redd","album":"A Love Letter To You 2","track_name":"Woah Woah Woah","album_cover_url":"https:\\/\\/i.scdn.co\\/image\\/ab67616d0000b273e991f37dbb44249ac01314f0","danceability":0.617,"popularity":48.0,"energy":0.773,"loudness":-4.793,"duration_ms":222288.0,"speechiness":0.0397,"instrumentalness":0.0,"liveness":0.204,"tempo":149.006,"tsne-one":-2.1635670662,"tsne-two":1.4950444698,"tsne-three":-1.9940937757},"3tcoEYOZUHKB3RKNByIN13":{"artist":"Lil Uzi Vert","album":"Luv Is Rage 2","track_name":"For Real","album_cover_url":"https:\\/\\/i.scdn.co\\/image\\/ab67616d0000b27341b41e6f7924e530a9b00f9c","danceability":0.902,"popularity":58.0,"energy":0.673,"loudness":-7.481,"duration_ms":177048.0,"speechiness":0.458,"instrumentalness":0.0,"liveness":0.289,"tempo":132.066,"tsne-one":-0.931829989,"tsne-two":-1.3138896227,"tsne-three":2.6212100983},"3QybPutx0Tjk472bBKjNWn":{"artist":"Sheck Wes","album":"Mo Bamba","track_name":"Mo Bamba","album_cover_url":"https:\\/\\/i.scdn.co\\/image\\/ab67616d0000b273a7d96c80aba617f9c335fdbe","danceability":0.738,"popularity":0.0,"energy":0.629,"loudness":-4.882,"duration_ms":180898.0,"speechiness":0.0495,"instrumentalness":0.00114,"liveness":0.163,"tempo":146.067,"tsne-one":-2.2732777596,"tsne-two":-2.9056665897,"tsne-three":-2.1063790321},"2bSk87AVkCIIC3Bcligq1z":{"artist":"Lil Baby","album":"Harder Than Ever","track_name":"Life Goes On","album_cover_url":"https:\\/\\/i.scdn.co\\/image\\/ab67616d0000b2736cab41f8c84d6164976400d4","danceability":0.716,"popularity":74.0,"energy":0.541,"loudness":-7.909,"duration_ms":247055.0,"speechiness":0.149,"instrumentalness":0.0,"liveness":0.115,"tempo":139.978,"tsne-one":2.0892539024,"tsne-two":1.7215743065,"tsne-three":0.0664985999},"5PTG6rrL6EPFD9E2QMI2pl":{"artist":"Famous Dex","album":"Dex Meets Dexter","track_name":"JAPAN","album_cover_url":"https:\\/\\/i.scdn.co\\/image\\/ab67616d0000b27324ef7429ba82789623ae8b14","danceability":0.733,"popularity":72.0,"energy":0.678,"loudness":-7.771,"duration_ms":142000.0,"speechiness":0.438,"instrumentalness":0.0,"liveness":0.344,"tempo":175.985,"tsne-one":-0.3766348362,"tsne-two":2.0807034969,"tsne-three":1.3030934334},"5lf3ajySox32qFvGEf2TFM":{"artist":"Lil Baby","album":"Harder Than Ever","track_name":"Southside","album_cover_url":"https:\\/\\/i.scdn.co\\/image\\/ab67616d0000b2736cab41f8c84d6164976400d4","danceability":0.813,"popularity":61.0,"energy":0.646,"loudness":-4.901,"duration_ms":173437.0,"speechiness":0.263,"instrumentalness":0.0,"liveness":0.191,"tempo":77.518,"tsne-one":-0.0403212793,"tsne-two":-0.0661840513,"tsne-three":1.6044925451},"27a1mYSG5tYg7dmEjWBcmL":{"artist":"Travis Scott","album":"ASTROWORLD","track_name":"CAN\'T SAY","album_cover_url":"https:\\/\\/i.scdn.co\\/image\\/ab67616d0000b273072e9faef2ef7b6db63834a3","danceability":0.702,"popularity":77.0,"energy":0.708,"loudness":-5.366,"duration_ms":198408.0,"speechiness":0.0547,"instrumentalness":0.0,"liveness":0.118,"tempo":147.98,"tsne-one":-0.9071843624,"tsne-two":2.7216765881,"tsne-three":0.7799037099} ...

# %%
test = pd.read_json(test)
test
# Out:
#                                              3UMpcCyG1Dj0yDb377vu2K  \
# artist                                          HoodRich Pablo Juan
# album                                                    Zambamafoo
# track_name                                               Zambamafoo
# album_cover_url   https://i.scdn.co/image/ab67616d0000b27319388d...
# danceability                                                  0.886
# popularity                                                       46
# energy                                                        0.644
# loudness                                                     -9.284
# duration_ms                                                  173493
# speechiness                                                   0.284
# instrumentalness                                                  0
# liveness                                                      0.161
# tempo                                                       119.992
# tsne-one                                                  -0.954939
# tsne-two                                                   -2.29384
# tsne-three                                                   1.4044
#
#                                              3x4KIuoye6F12loCFckCX3  \
# artist                                              Various Artists
# album                                                  DJ Worldtour
# track_name              That's My Rule (Intro) [feat. Lil Uzi Vert]
# album_cover_url   https://i.scdn.co/image/ab67616d0000b273005ac5...
# danceability                                                  0.908
# popularity                                                        0
# energy                                                        0.695
# loudness                                                       -7.1
# duration_ms                                                  166792
# speechiness                                                   0.269
# instrumentalness                                                  0
# liveness                                                       0.27
# tempo                                                       144.026
# tsne-one                                                   -2.53386
# tsne-two                                                   -3.38039
# tsne-three                                                -0.766466
#
#                                              70NxaxjB8IjX4YxXbT90iX  \
# artist                                                 Trippie Redd
# album                                        A Love Letter To You 2
# track_name                                           Woah Woah Woah
# album_cover_url   https://i.scdn.co/image/ab67616d0000b273e991f3...
# danceability                                                  0.617
# popularity                                                       48
# energy                                                        0.773
# loudness                                                     -4.793
# duration_ms                                                  222288
# speechiness                                                  0.0397
# instrumentalness                                                  0
# liveness                                                      0.204
# tempo                                                       149.006
# tsne-one                                                   -2.16357
# tsne-two                                                    1.49504
# tsne-three                                                 -1.99409
#
#                                              3tcoEYOZUHKB3RKNByIN13  \
# artist                                                 Lil Uzi Vert
# album                                                 Luv Is Rage 2
# track_name                                                 For Real
# album_cover_url   https://i.scdn.co/image/ab67616d0000b27341b41e...
# danceability                                                  0.902
# popularity                                                       58
# energy                                                        0.673
# loudness                                                     -7.481
# duration_ms                                                  177048
# speechiness                                                   0.458
# instrumentalness                                                  0
# liveness                                                      0.289
# tempo                                                       132.066
# tsne-one                                                   -0.93183
# tsne-two                                                   -1.31389
# tsne-three                                                  2.62121
#
#                                              3QybPutx0Tjk472bBKjNWn  \
# artist                                                    Sheck Wes
# album                                                      Mo Bamba
# track_name                                                 Mo Bamba
# album_cover_url   https://i.scdn.co/image/ab67616d0000b273a7d96c...
# danceability                                                  0.738
# popularity                                                        0
# energy                                                        0.629
# loudness                                                     -4.882
# duration_ms                                                  180898
# speechiness                                                  0.0495
# instrumentalness                                            0.00114
# liveness                                                      0.163
# tempo                                                       146.067
# tsne-one                                                   -2.27328
# tsne-two                                                   -2.90567
# tsne-three                                                 -2.10638
#
#                                              2bSk87AVkCIIC3Bcligq1z  \
# artist                                                     Lil Baby
# album                                              Harder Than Ever
# track_name                                             Life Goes On
# album_cover_url   https://i.scdn.co/image/ab67616d0000b2736cab41...
# danceability                                                  0.716
# popularity                                                       74
# energy                                                        0.541
# loudness                                                     -7.909
# duration_ms                                                  247055
# speechiness                                                   0.149
# instrumentalness                                                  0
# liveness                                                      0.115
# tempo                                                       139.978
# tsne-one                                                    2.08925
# tsne-two                                                    1.72157
# tsne-three                                                0.0664986
#
#                                              5PTG6rrL6EPFD9E2QMI2pl  \
# artist                                                   Famous Dex
# album                                              Dex Meets Dexter
# track_name                                                    JAPAN
# album_cover_url   https://i.scdn.co/image/ab67616d0000b27324ef74...
# danceability                                                  0.733
# popularity                                                       72
# energy                                                        0.678
# loudness                                                     -7.771
# duration_ms                                                  142000
# speechiness                                                   0.438
# instrumentalness                                                  0
# liveness                                                      0.344
# tempo                                                       175.985
# tsne-one                                                  -0.376635
# tsne-two                                                     2.0807
# tsne-three                                                  1.30309
#
#                                              5lf3ajySox32qFvGEf2TFM  \
# artist                                                     Lil Baby
# album                                              Harder Than Ever
# track_name                                                Southside
# album_cover_url   https://i.scdn.co/image/ab67616d0000b2736cab41...
# danceability                                                  0.813
# popularity                                                       61
# energy                                                        0.646
# loudness                                                     -4.901
# duration_ms                                                  173437
# speechiness                                                   0.263
# instrumentalness                                                  0
# liveness                                                      0.191
# tempo                                                        77.518
# tsne-one                                                 -0.0403213
# tsne-two                                                 -0.0661841
# tsne-three                                                  1.60449
#
#                                              27a1mYSG5tYg7dmEjWBcmL  \
# artist                                                 Travis Scott
# album                                                    ASTROWORLD
# track_name                                                CAN'T SAY
# album_cover_url   https://i.scdn.co/image/ab67616d0000b273072e9f...
# danceability                                                  0.702
# popularity                                                       77
# energy                                                        0.708
# loudness                                                     -5.366
# duration_ms                                                  198408
# speechiness                                                  0.0547
# instrumentalness                                                  0
# liveness                                                      0.118
# tempo                                                        147.98
# tsne-one                                                  -0.907184
# tsne-two                                                    2.72168
# tsne-three                                                 0.779904
#
#                                              2xLMifQCjDGFmkHkpNLD9h  ...  \
# artist                                                 Travis Scott  ...
# album                                                    ASTROWORLD  ...
# track_name                                               SICKO MODE  ...
# album_cover_url   https://i.scdn.co/image/ab67616d0000b273072e9f...  ...
# danceability                                                  0.834  ...
# popularity                                                       84  ...
# energy                                                         0.73  ...
# loudness                                                     -3.714  ...
# duration_ms                                                  312820  ...
# speechiness                                                   0.222  ...
# instrumentalness                                                  0  ...
# liveness                                                      0.124  ...
# tempo                                                       155.008  ...
# tsne-one                                                   -1.48113  ...
# tsne-two                                                    1.77748  ...
# tsne-three                                                    2.789  ...
#
#                                              4s7QLoImIwmPi9L6dq1nVW  \
# artist                                                        Drake
# album                                           Certified Lover Boy
# track_name                                                      TSU
# album_cover_url   https://i.scdn.co/image/ab67616d0000b273cd945b...
# danceability                                                  0.568
# popularity                                                       83
# energy                                                         0.56
# loudness                                                     -9.059
# duration_ms                                                  308756
# speechiness                                                    0.42
# instrumentalness                                           3.05e-06
# liveness                                                       0.39
# tempo                                                       130.019
# tsne-one                                                    1.50603
# tsne-two                                                    2.98014
# tsne-three                                                 -1.46891
#
#                                              7F9cT6hIRhnFCYP6GKS0tf  \
# artist                                                        Drake
# album                                           Certified Lover Boy
# track_name                                     IMY2 (with Kid Cudi)
# album_cover_url   https://i.scdn.co/image/ab67616d0000b273cd945b...
# danceability                                                   0.59
# popularity                                                       81
# energy                                                        0.493
# loudness                                                     -8.704
# duration_ms                                                  252379
# speechiness                                                  0.0367
# instrumentalness                                            0.00504
# liveness                                                      0.129
# tempo                                                       150.026
# tsne-one                                                    1.89859
# tsne-two                                                    2.77856
# tsne-three                                                 -1.62791
#
#                                              6pmNoWKk0r6zfIjWneJRxR  \
# artist                                                       DaBaby
# album                                       Lonely (with Lil Wayne)
# track_name                                  Lonely (with Lil Wayne)
# album_cover_url   https://i.scdn.co/image/ab67616d0000b27322ff72...
# danceability                                                  0.718
# popularity                                                       81
# energy                                                        0.628
# loudness                                                     -5.334
# duration_ms                                                  154433
# speechiness                                                   0.373
# instrumentalness                                                  0
# liveness                                                      0.186
# tempo                                                       139.769
# tsne-one                                                   0.456465
# tsne-two                                                    2.79264
# tsne-three                                                 0.713428
#
#                                              1Is8hGpkGMiePASAxBluxM  \
# artist                                                    Baby Keem
# album                                              The Melodic Blue
# track_name                                                       16
# album_cover_url   https://i.scdn.co/image/ab67616d0000b2731bfa23...
# danceability                                                  0.701
# popularity                                                       75
# energy                                                        0.782
# loudness                                                     -4.987
# duration_ms                                                  156040
# speechiness                                                   0.138
# instrumentalness                                           2.31e-06
# liveness                                                      0.124
# tempo                                                         94.03
# tsne-one                                                   -1.95529
# tsne-two                                                    2.54661
# tsne-three                                                  1.28451
#
#                                              0e8nrvls4Qqv5Rfa2UhqmO  \
# artist                                                    Lil Nas X
# album                                                       MONTERO
# track_name                                        THATS WHAT I WANT
# album_cover_url   https://i.scdn.co/image/ab67616d0000b273be8267...
# danceability                                                  0.737
# popularity                                                       95
# energy                                                        0.846
# loudness                                                      -4.51
# duration_ms                                                  143901
# speechiness                                                    0.22
# instrumentalness                                                  0
# liveness                                                     0.0486
# tempo                                                        87.981
# tsne-one                                                   -2.19058
# tsne-two                                                     2.6274
# tsne-three                                                  1.84991
#
#                                              5bBzkJE9BqYTL27webAUCw  \
# artist                                                       Remble
# album                              Rocc Climbing (feat. Lil Yachty)
# track_name                         Rocc Climbing (feat. Lil Yachty)
# album_cover_url   https://i.scdn.co/image/ab67616d0000b273efb947...
# danceability                                                  0.832
# popularity                                                       69
# energy                                                        0.656
# loudness                                                     -7.492
# duration_ms                                                  175878
# speechiness                                                   0.375
# instrumentalness                                           2.13e-06
# liveness                                                      0.108
# tempo                                                       100.032
# tsne-one                                                  -0.181451
# tsne-two                                                   0.496111
# tsne-three                                                  2.69201
#
#                                              34D6FJysnQioVingDKufuf  \
# artist                                                        Drake
# album                                           Certified Lover Boy
# track_name                                                 N 2 Deep
# album_cover_url   https://i.scdn.co/image/ab67616d0000b273cd945b...
# danceability                                                  0.507
# popularity                                                       82
# energy                                                        0.429
# loudness                                                     -7.726
# duration_ms                                                  273578
# speechiness                                                   0.326
# instrumentalness                                                  0
# liveness                                                      0.109
# tempo                                                            91
# tsne-one                                                    1.89884
# tsne-two                                                    2.86353
# tsne-three                                                 -2.04679
#
#                                              4yNoUQkYf1QF8iYlEzNynH  \
# artist                                                   Nardo Wick
# album             Who Want Smoke?? (feat. G Herbo, Lil Durk & 21...
# track_name        Who Want Smoke?? (feat. G Herbo, Lil Durk & 21...
# album_cover_url   https://i.scdn.co/image/ab67616d0000b273f26d2f...
# danceability                                                  0.739
# popularity                                                       81
# energy                                                         0.74
# loudness                                                      -5.86
# duration_ms                                                  279853
# speechiness                                                   0.333
# instrumentalness                                                  0
# liveness                                                      0.161
# tempo                                                        75.575
# tsne-one                                                   -1.57528
# tsne-two                                                    2.59029
# tsne-three                                                  1.74642
#
#                                              5JrljwNvTFN6y7b5a5Nzq7  \
# artist                                                The Kid LAROI
# album                                        F*CK LOVE 3+: OVER YOU
# track_name                                                ATTENTION
# album_cover_url   https://i.scdn.co/image/ab67616d0000b273b4d59e...
# danceability                                                  0.878
# popularity                                                       64
# energy                                                        0.583
# loudness                                                     -7.053
# duration_ms                                                  104525
# speechiness                                                  0.0729
# instrumentalness                                                  0
# liveness                                                      0.393
# tempo                                                       132.939
# tsne-one                                                   0.883633
# tsne-two                                                   -1.04728
# tsne-three                                                  2.28641
#
#                                              6oFJuAS9OYFfMRFJ08SI1S
# artist                                                The Kid LAROI
# album                                        F*CK LOVE 3+: OVER YOU
# track_name                                                 BAD NEWS
# album_cover_url   https://i.scdn.co/image/ab67616d0000b273b4d59e...
# danceability                                                   0.55
# popularity                                                       60
# energy                                                        0.533
# loudness                                                     -6.853
# duration_ms                                                  131365
# speechiness                                                  0.0441
# instrumentalness                                                  0
# liveness                                                       0.12
# tempo                                                         87.48
# tsne-one                                                    1.15399
# tsne-two                                                    2.16188
# tsne-three                                                 -2.67585
#
# [16 rows x 1483 columns]

# %%
test.to_json('tsneLargeDataset.json')
test.iloc[:, 0:50].to_json('tsneToyDataset.json')
test.iloc[:, 0:100].to_json('tsne100Dataset.json')
test.iloc[:, 0:400].to_json('tsne400Dataset.json')
test.iloc[:, 0:800].to_json('tsne800Dataset.json')

# %%
with open('tsneToyDataset.json') as json_file:
    data = json.load(json_file)
len(data)
# pd.read_json('tsneToyDataset')
# Out:
# 50
